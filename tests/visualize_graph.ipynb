# %% [markdown]
# # ClusterDoctor LangGraph 시각화
#
# `build_graph()`로 만들어지는 StateGraph를 그림으로 확인합니다.

# %%
import sys, os

# 노트북이 tests/ 에 있으므로 프로젝트 루트의 src를 경로에 추가
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

print("project_root:", project_root)

# %%
from cluster_doctor.infrastructure.outbound.llm.langgraph.graph import build_graph

# LLM을 실제로 호출하지 않는 더미 caller
def dummy_llm(prompt: str) -> str:
    return "dummy"

graph = build_graph(call_llm=dummy_llm, call_llm_minute=None)
print("그래프 빌드 완료")

# %% [markdown]
# ## ASCII 다이어그램 (의존성 없음)

# %% [markdown]
# ## LangGraph
#
# `pip install playwright && playwright install chromium` 또는
# `pip install graphviz pygraphviz` 설치 후 실행하세요.

# %%
from IPython.display import Image, display

try:
    png = graph.get_graph().draw_mermaid_png()
    display(Image(png))
except Exception as e:
    print(f"PNG 렌더링 실패: {e}")
    print("위의 ASCII 다이어그램이나 Mermaid 소스를 사용하세요.")
